# %%
import pandas as pd

# %%
import re
import pandas as pd
import fitz  # PyMuPDF

# Sample PDF file
pdf_file = "sample.pdf"  # Replace with your PDF file

# Keywords to search for
keywords = ["Data Science", "Python", "Machine Learning", "Analytics"]

# Create a PDF document object
doc = fitz.open(pdf_file)

# Initialize a list to store keyword matches
matches = []

# Iterate through each page in the PDF
for page_num in range(doc.page_count):
    page = doc.load_page(page_num)
    text = page.get_text("blocks")
    
    # Iterate through each block (paragraph) on the page
    for block in text:
        paragraph_text = block[4]
        
        # Check for keyword matches in the paragraph
        for keyword in keywords:
            if re.search(r'\b{}\b'.format(keyword), paragraph_text, re.IGNORECASE):
                match_info = {
                    "Keyword": keyword,
                    "Page": page_num + 1,  # Adding 1 to convert 0-based to 1-based indexing
                    "Paragraph": paragraph_text
                }
                matches.append(match_info)

# Close the PDF document
doc.close()

# Create a DataFrame from matches
result_df = pd.DataFrame(matches)

# Print the resulting DataFrame
print(result_df)

# %%
import pandas as pd
import fitz  # PyMuPDF

# Sample PDF file
pdf_file = "sample.pdf"  # Replace with your PDF file

# Read the column values from a DataFrame (replace this with your own data)
data = {'ColumnToMatch': ['Data Science', 'Python', 'Machine Learning']}
df = pd.DataFrame(data)

# Create a PDF document object
doc = fitz.open(pdf_file)

# Initialize a list to store match information
matches = []

# Iterate through each page in the PDF
for page_num in range(doc.page_count):
    page = doc.load_page(page_num)
    text = page.get_text("blocks")
    
    # Iterate through each block (paragraph) on the page
    for block in text:
        paragraph_text = block[4]
        
        # Check for matches with each value in the column
        for index, row in df.iterrows():
            value_to_match = row['ColumnToMatch']
            if value_to_match in paragraph_text:
                match_info = {
                    "ValueToMatch": value_to_match,
                    "Page": page_num + 1,  # Adding 1 to convert 0-based to 1-based indexing
                    "Paragraph": paragraph_text
                }
                matches.append(match_info)

# Close the PDF document
doc.close()

# Create a DataFrame from matches
result_df = pd.DataFrame(matches)

# Print the resulting DataFrame
print(result_df)

# %%
import PyPDF2
import pandas as pd

# Load your table data into a pandas DataFrame
# Replace this with your actual table data
table_data = pd.DataFrame({
    'ID': [1, 2, 3],
    'Keyword': ['Keyword1', 'Keyword2', 'Keyword3']
})

# Open the PDF file
pdf_path = 'your_pdf_file.pdf'
pdf_file = open(pdf_path, 'rb')

# Create a PDF reader object
pdf_reader = PyPDF2.PdfReader(pdf_file)

# Initialize variables to store matching results
matching_results = []

# Loop through each page in the PDF
for page_number, page in enumerate(pdf_reader.pages, start=1):
    page_text = page.extract_text()
    
    # Loop through each row in the table data
    for index, row in table_data.iterrows():
        keyword = row['Keyword']
        keyword_occurrences = page_text.count(keyword)
        
        if keyword_occurrences > 0:
            matching_results.append({
                'Keyword': keyword,
                'Page Number': page_number,
                'Keyword Occurrences': keyword_occurrences
            })

# Close the PDF file
pdf_file.close()

# Display the matching results
matching_df = pd.DataFrame(matching_results)
print(matching_df)

# %%
import PyPDF2
import pandas as pd

# Load your table data into a pandas DataFrame
# Replace this with your actual table data
table_data = pd.DataFrame({
    'ID': [1, 2, 3],
    'Keyword': ['Keyword1', 'Keyword2', 'Keyword3']
})

# Open the PDF file
pdf_path = 'your_pdf_file.pdf'
pdf_file = open(pdf_path, 'rb')

# Create a PDF reader object
pdf_reader = PyPDF2.PdfReader(pdf_file)

# Initialize variables to store matching results
matching_results = []

# Loop through each page in the PDF
for page_number, page in enumerate(pdf_reader.pages, start=1):
    page_text = page.extract_text()
    
    # Loop through each row in the table data
    for index, row in table_data.iterrows():
        keyword = row['Keyword']
        keyword_occurrences = page_text.count(keyword)
        
        if keyword_occurrences > 0:
            matching_results.append({
                'Keyword': keyword,
                'Page Number': page_number,
                'Keyword Occurrences': keyword_occurrences
            })

# Close the PDF file
pdf_file.close()

# Display the matching results
matching_df = pd.DataFrame(matching_results)
print(matching_df)

# %%
matching_results = []

for index, row in excel_data.iterrows():
    title = row['Title']
    description = row['Description']
    
    matched_keywords = []
    
    for page_number, page_text in enumerate(pdf_text, start=1):
        for keyword in description.split('\n'):
            if keyword.lower() in page_text.lower():
                matched_keywords.append(keyword)
                
                matching_results.append({
                    'Title': title,
                    'Description': description,
                    'Matched Keywords': matched_keywords,
                    'Page Number': page_number
                })

matching_df = pd.DataFrame(matching_results)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF text and prepare Excel data) ...

matching_results = []

for index, row in excel_data.iterrows():
    title = row['Title']
    description = row['Description']
    
    matched_keywords = []
    
    for page_number, page_text in enumerate(pdf_text, start=1):
        for keyword in description.split('\n'):
            keyword = keyword.strip()  # Remove leading/trailing whitespace
            
            # Perform fuzzy matching
            for word in page_text.split():
                similarity = fuzz.partial_ratio(keyword.lower(), word.lower())
                if similarity >= 80:  # You can adjust this threshold
                    matched_keywords.append(keyword)
                    break  # Move to the next keyword
            
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Page Number': page_number
            })

matching_df = pd.DataFrame(matching_results)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF text and prepare Excel data) ...

matching_results = []

for index, row in excel_data.iterrows():
    title = row['Title']
    description = row['Description']
    
    for page_number, page_text in enumerate(pdf_text, start=1):
        matched_keywords = []
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()  # Remove leading/trailing whitespace
            
            best_match = None
            best_score = 0
            
            for word in page_text.split():
                similarity = fuzz.partial_ratio(keyword.lower(), word.lower())
                if similarity > best_score:
                    best_score = similarity
                    best_match = word
            
            if best_match:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': best_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Page Number': page_number
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    page_number = result['Page Number']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Page Number': page_number
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF text and prepare Excel data) ...

matching_results = []

for index, row in excel_data.iterrows():
    title = row['Title']
    description = row['Description']
    
    for page_number, page_text in enumerate(pdf_text, start=1):
        matched_keywords = []
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()  # Remove leading/trailing whitespace
            
            best_match = None
            best_score = 0
            
            for word in page_text.split():
                similarity = fuzz.partial_ratio(keyword.lower(), word.lower())
                if similarity > best_score:
                    best_score = similarity
                    best_match = word
            
            if best_match:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': best_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Page Number': page_number
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    page_number = result['Page Number']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Page Number': page_number
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF text and prepare Excel data) ...

matching_results = []

for index, row in excel_data.iterrows():
    title = row['Title']
    description = row['Description']
    
    for page_number, page_text in enumerate(pdf_text, start=1):
        matched_keywords = []
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()  # Remove leading/trailing whitespace
            
            # Find the best match for the keyword in the page text
            best_match, match_score = process.extractOne(keyword.lower(), page_text.lower().split())
            
            if match_score >= 80:  # You can adjust this threshold
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Page Number': page_number  # Corrected page number tracking
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    page_number = result['Page Number']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Page Number': page_number
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2

def extract_pdf_paragraphs(pdf_path):
    with open(pdf_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        paragraphs = []
        for page in pdf_reader.pages:
            page_text = page.extract_text()
            page_paragraphs = page_text.split('\n\n')  # Split by double newline to get paragraphs
            paragraphs.extend(page_paragraphs)
        return paragraphs

pdf_paragraphs = extract_pdf_paragraphs('your_pdf_file.pdf')

# %%
from rapidfuzz import fuzz

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        
        matched_keywords = []
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()
            
            best_match, match_score = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Paragraph Number': paragraph_number
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    paragraph_number = result['Paragraph Number']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Paragraph Number': paragraph_number
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        
        matched_keywords = []
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Matched Keywords': matched_keywords,
                'Paragraph Number': paragraph_number,
                'Paragraph Text': paragraph_text
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Paragraph Number': paragraph_number,
            'Paragraph Text': paragraph_text
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        keywords = f"{title}\n{description}\n{objective}"  # Concatenate Title, Description, and Objective
        
        matched_keywords = []
        
        for keyword in keywords.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Keywords': matched_keywords,
                'Paragraph Number': paragraph_number,
                'Paragraph Text': paragraph_text
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    objective = result['Objective']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Objective': objective,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Paragraph Number': paragraph_number,
            'Paragraph Text': paragraph_text
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        matched_keywords = []
        
        for keyword in title.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })

        for keyword in description.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })

        for keyword in objective.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Keywords': matched_keywords,
                'Paragraph Number': paragraph_number,
                'Paragraph Text': paragraph_text
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    objective = result['Objective']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Objective': objective,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Paragraph Number': paragraph_number,
            'Paragraph Text': paragraph_text
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
#mathing_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        matched_keywords = []
        
        for keyword in title.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })

        for keyword in description.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })

        for keyword in objective.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_keywords.append({
                    'Keyword': keyword,
                    'Matched Word': best_match,
                    'Match Score': match_score
                })
        
        if matched_keywords:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Keywords': matched_keywords,
                'Paragraph Number': paragraph_number,
                'Paragraph Text': paragraph_text
            })

# Create a new DataFrame to store the results with matched keywords and scores
result_data = []
for result in matching_results:
    title = result['Title']
    description = result['Description']
    objective = result['Objective']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    for keyword_info in result['Matched Keywords']:
        keyword = keyword_info['Keyword']
        matched_word = keyword_info['Matched Word']
        match_score = keyword_info['Match Score']
        result_data.append({
            'Title': title,
            'Description': description,
            'Objective': objective,
            'Keyword': keyword,
            'Matched Word': matched_word,
            'Match Score': match_score,
            'Paragraph Number': paragraph_number,
            'Paragraph Text': paragraph_text
        })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
##For separately comparing them without keywords

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        matched_titles = []
        matched_descriptions = []
        matched_objectives = []
        
        if fuzz.ratio(title.lower(), paragraph_text.lower()) >= 80:
            matched_titles.append(title)
        
        if fuzz.ratio(description.lower(), paragraph_text.lower()) >= 80:
            matched_descriptions.append(description)
        
        if fuzz.ratio(objective.lower(), paragraph_text.lower()) >= 80:
            matched_objectives.append(objective)
        
        if matched_titles or matched_descriptions or matched_objectives:
            matching_results.append({
                'Matched Titles': matched_titles,
                'Matched Descriptions': matched_descriptions,
                'Matched Objectives': matched_objectives,
                'Paragraph Number': paragraph_number,
                'Paragraph Text': paragraph_text
            })

# Create a new DataFrame to store the results
result_data = []
for result in matching_results:
    matched_titles = result['Matched Titles']
    matched_descriptions = result['Matched Descriptions']
    matched_objectives = result['Matched Objectives']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    
    result_data.append({
        'Matched Titles': matched_titles,
        'Matched Descriptions': matched_descriptions,
        'Matched Objectives': matched_objectives,
        'Paragraph Number': paragraph_number,
        'Paragraph Text': paragraph_text
    })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    matched_titles = []
    matched_descriptions = []
    matched_objectives = []
    
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        if fuzz.ratio(title.lower(), paragraph_text.lower()) >= 80:
            matched_titles.append(title)
        
        if fuzz.ratio(description.lower(), paragraph_text.lower()) >= 80:
            matched_descriptions.append(description)
        
        if fuzz.ratio(objective.lower(), paragraph_text.lower()) >= 80:
            matched_objectives.append(objective)
        
    if matched_titles or matched_descriptions or matched_objectives:
        matching_results.append({
            'All Titles': excel_data['Title'].tolist(),
            'All Descriptions': excel_data['Description'].tolist(),
            'All Objectives': excel_data['Objective'].tolist(),
            'Matched Titles': matched_titles,
            'Matched Descriptions': matched_descriptions,
            'Matched Objectives': matched_objectives,
            'Paragraph Number': paragraph_number,
            'Paragraph Text': paragraph_text
        })

# Create a new DataFrame to store the results
result_data = []
for result in matching_results:
    all_titles = result['All Titles']
    all_descriptions = result['All Descriptions']
    all_objectives = result['All Objectives']
    matched_titles = result['Matched Titles']
    matched_descriptions = result['Matched Descriptions']
    matched_objectives = result['Matched Objectives']
    paragraph_number = result['Paragraph Number']
    paragraph_text = result['Paragraph Text']
    
    result_data.append({
        'All Titles': all_titles,
        'All Descriptions': all_descriptions,
        'All Objectives': all_objectives,
        'Matched Titles': matched_titles,
        'Matched Descriptions': matched_descriptions,
        'Matched Objectives': matched_objectives,
        'Paragraph Number': paragraph_number,
        'Paragraph Text': paragraph_text
    })

matching_df = pd.DataFrame(result_data)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        matched_title_keywords = []
        matched_description_keywords = []
        matched_objective_keywords = []
        
        if fuzz.ratio(title.lower(), paragraph_text.lower()) >= 80:
            matched_title_keywords.extend(title.split('\n'))
        
        if fuzz.ratio(description.lower(), paragraph_text.lower()) >= 80:
            matched_description_keywords.extend(description.split('\n'))
        
        if fuzz.ratio(objective.lower(), paragraph_text.lower()) >= 80:
            matched_objective_keywords.extend(objective.split('\n'))
        
        if matched_title_keywords or matched_description_keywords or matched_objective_keywords:
            matching_results.append({
                'Matched Paragraph': paragraph_text,
                'Matched Page Number': paragraph_number,
                'Matched Title Keywords': ', '.join(matched_title_keywords),
                'Matched Description Keywords': ', '.join(matched_description_keywords),
                'Matched Objective Keywords': ', '.join(matched_objective_keywords)
            })

# Create a new DataFrame to store the results
matching_df = pd.DataFrame(matching_results)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import process

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        matched_title_keywords = []
        matched_description_keywords = []
        matched_objective_keywords = []
        
        for keyword in title.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_title_keywords.append(f"{best_match} (Score: {match_score})")
        
        for keyword in description.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_description_keywords.append(f"{best_match} (Score: {match_score})")
        
        for keyword in objective.split('\n'):
            keyword = keyword.strip()
            
            best_match_info = process.extractOne(keyword.lower(), paragraph_text.lower().split())
            best_match = best_match_info[0]
            match_score = best_match_info[1]
            
            if match_score >= 80:
                matched_objective_keywords.append(f"{best_match} (Score: {match_score})")
        
        if matched_title_keywords or matched_description_keywords or matched_objective_keywords:
            matching_results.append({
                'Matched Paragraph': paragraph_text,
                'Matched Page Number': paragraph_number,
                'Matched Title Keywords': ', '.join(matched_title_keywords),
                'Matched Description Keywords': ', '.join(matched_description_keywords),
                'Matched Objective Keywords': ', '.join(matched_objective_keywords)
            })

# Create a new DataFrame to store the results
matching_df = pd.DataFrame(matching_results)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)

# %%
import PyPDF2
import pandas as pd
from rapidfuzz import fuzz

# ... (same code as before to extract PDF paragraphs and prepare Excel data) ...

matching_results = []

for paragraph_number, paragraph_text in enumerate(pdf_paragraphs, start=1):
    for index, row in excel_data.iterrows():
        title = row['Title']
        description = row['Description']
        objective = row['Objective']
        
        title_score = fuzz.ratio(title.lower(), paragraph_text.lower())
        description_score = fuzz.ratio(description.lower(), paragraph_text.lower())
        objective_score = fuzz.ratio(objective.lower(), paragraph_text.lower())
        
        if title_score >= 80:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Paragraph': paragraph_text,
                'Matched Page Number': paragraph_number,
                'Matched Score': title_score
            })
        
        if description_score >= 80:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Paragraph': paragraph_text,
                'Matched Page Number': paragraph_number,
                'Matched Score': description_score
            })
        
        if objective_score >= 80:
            matching_results.append({
                'Title': title,
                'Description': description,
                'Objective': objective,
                'Matched Paragraph': paragraph_text,
                'Matched Page Number': paragraph_number,
                'Matched Score': objective_score
            })

# Create a new DataFrame to store the results
matching_df = pd.DataFrame(matching_results)

# Save the matching results to a CSV file
matching_df.to_csv('matching_results.csv', index=False)
