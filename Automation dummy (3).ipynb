# %%
import pandas as pd

# Create the datasets A and B
data_A = {
    'ID': ['ABC-1', 'ABC-2', 'ABC-3', 'ABC-4', 'ABC-5', 'ABC-6'],
    'status': ['on track', 'not on track', 'delayed', 'on track', 'on track', 'delayed'],
    'login date': ['31-May-22', '04-Mar-22', '15-May-21', '17-Apr-23', '04-Sep-21', '06-Aug-22'],
    'places date': ['02-Jul-21', '10-Mar-22', '21-Jun-21', '01-May-23', '01-Oct-21', '17-Aug-22'],
    'tracking': ['yes', 'no', 'no', 'yes', 'yes', 'yes']
}

data_B = {
    'ID': ['ABC-1', 'ABC-2', 'ABC-10', 'ABC-4', 'ABC-12', 'ABC-17'],
    'status': ['not on track', 'on track', 'delayed', 'on track', 'on track', 'delayed'],
    'login date': ['31-Jul-22', '10-Apr-22', '15-May-21', '20-May-23', '04-Sep-21', '06-Aug-22'],
    'places date': ['02-Jul-21', '10-Mar-22', '21-Jun-21', '01-May-23', '01-Oct-21', '17-Aug-22']
}

df_A = pd.DataFrame(data_A)
df_B = pd.DataFrame(data_B)

# Replace values in A with B based on the specified conditions
for index, row in df_B.iterrows():
    id_match = df_A['ID'] == row['ID']
    tracking_match = df_A['tracking'] == 'yes'
    df_A.loc[id_match & tracking_match, 'status'] = row['status']
    df_A.loc[id_match & tracking_match, 'login date'] = row['login date']

print(df_A)

# %%
# Convert the dictionaries to pandas DataFrames
df_a = pd.DataFrame(data_a)
df_b = pd.DataFrame(data_b)

# Filter dataset A based on the conditions (ID is same and "tracking" is "yes" and confidential is "internal")
filtered_a = df_a[(df_a["ID"].isin(df_b["ID"])) & (df_a["tracking"] == "yes") & (df_a["confidential"] == "internal")]

# Merge dataset A with dataset B on "ID" and update the columns "status" and "login date"
merged_data = pd.merge(filtered_a, df_b[["ID", "status", "login date"]], on="ID", suffixes=("_A", "_B"))

# Drop the original "status" and "login date" columns and rename the new ones
merged_data.drop(columns=["status_A", "login date_A"], inplace=True)
merged_data.rename(columns={"status_B": "status", "login date_B": "login date"}, inplace=True)

# Update the original dataset A with the modified data
df_a.update(merged_data)

# Display the final updated dataset A
print(df_a)

# %%
# Create pandas DataFrames from the sample data
df_a = pd.DataFrame(data_a)
df_b = pd.DataFrame(data_b)

# Set ID as the index for both DataFrames for easier merging
df_a.set_index('ID', inplace=True)
df_b.set_index('ID', inplace=True)

# Filter dataset A based on the conditions: tracking is "yes" and confidential is "internal"
filtered_df_a = df_a[(df_a['tracking'] == 'yes') & (df_a['confidential'] == 'internal')]

# Perform the replacement based on the matching IDs
df_a.update(df_b, overwrite=True)

# Restore the filtered rows back to dataset A
df_a.update(filtered_df_a)

# Reset the index to get the ID back as a column
df_a.reset_index(inplace=True)

# Print the updated dataset A
print(df_a)

# %%
import pandas as pd

# Sample data for dataset A
data_a = {
    'ID': ['ABC-1', 'ABC-2', 'ABC-3', 'ABC-4', 'ABC-5', 'ABC-6'],
    'status': ['on track', 'not on track', 'delayed', 'on track', 'on track', 'delayed'],
    'login date': ['31-May-22', '04-Mar-22', '15-May-21', '17-Apr-23', '04-Sep-21', '06-Aug-22'],
    'places date': ['02-Jul-21', '10-Mar-22', '21-Jun-21', '01-May-23', '01-Oct-21', '17-Aug-22'],
    'tracking': ['yes', 'No', 'No', 'yes', 'yes', 'yes'],
    'confidential': ['internal', 'internal', 'internal', 'internal', 'internal', 'internal']
}

# Sample data for dataset B
data_b = {
    'ID': ['ABC-1', 'ABC-2', 'ABC-10', 'ABC-4', 'ABC-12', 'ABC-17'],
    'status': ['not on track', 'on track', 'delayed', 'on track', 'on track', 'delayed'],
    'login date': ['31-Jul-22', '10-Apr-22', '15-May-21', '20-May-23', '04-Sep-21', '06-Aug-22'],
    'places date': ['02-Jul-21', '10-Mar-22', '21-Jun-21', '01-May-23', '01-Oct-21', '17-Aug-22']
}

# Create pandas DataFrames from the sample data
df_a = pd.DataFrame(data_a)
df_b = pd.DataFrame(data_b)

# Filter dataset A based on the conditions: tracking is "yes" and confidential is "internal"
filtered_df_a = df_a[(df_a['tracking'] == 'yes') & (df_a['confidential'] == 'internal')]

# Merge datasets A and B based on ID
merged_df = pd.merge(df_a, df_b, on='ID', suffixes=('_A', '_B'), how='left')
merged_df
# Out:
#       ID      status_A login date_A places date_A tracking confidential  \
# 0  ABC-1      on track    31-May-22     02-Jul-21      yes     internal
# 1  ABC-2  not on track    04-Mar-22     10-Mar-22       No     internal
# 2  ABC-3       delayed    15-May-21     21-Jun-21       No     internal
# 3  ABC-4      on track    17-Apr-23     01-May-23      yes     internal
# 4  ABC-5      on track    04-Sep-21     01-Oct-21      yes     internal
# 5  ABC-6       delayed    06-Aug-22     17-Aug-22      yes     internal
#
#        status_B login date_B places date_B
# 0  not on track    31-Jul-22     02-Jul-21
# 1      on track    10-Apr-22     10-Mar-22
# 2           NaN          NaN           NaN
# 3      on track    20-May-23     01-May-23
# 4           NaN          NaN           NaN
# 5           NaN          NaN           NaN

# %%
# Function to get the desired status and login date based on the conditions
def get_updated_status(row):
    if row['tracking'] == 'yes' and row['confidential'] == 'internal':
        return row['status_B']
    return row['status_A']

def get_updated_login_date(row):
    if row['tracking'] == 'yes' and row['confidential'] == 'internal':
        return row['login date_B']
    return row['login date_A']

# Apply the functions to get the updated values for status and login date
merged_df['status'] = merged_df.apply(get_updated_status, axis=1)
merged_df['login date'] = merged_df.apply(get_updated_login_date, axis=1)

# Drop unnecessary columns from the merged DataFrame
merged_df.drop(columns=['status_A', 'status_B', 'login date_A', 'login date_B'], inplace=True)

# Restore the filtered rows back to dataset A
updated_df_a = pd.concat([merged_df, filtered_df_a]).drop_duplicates()

# Reset the index to get the ID back as a column
updated_df_a.reset_index(drop=True, inplace=True)

# Print the updated dataset A
print(updated_df_a)
# Out:
#       ID places date_A tracking confidential places date_B        status  \
# 0  ABC-1     02-Jul-21      yes     internal     02-Jul-21  not on track
# 1  ABC-2     10-Mar-22       No     internal     10-Mar-22  not on track
# 2  ABC-3     21-Jun-21       No     internal           NaN       delayed
# 3  ABC-4     01-May-23      yes     internal     01-May-23      on track
# 4  ABC-5     01-Oct-21      yes     internal           NaN           NaN
# 5  ABC-6     17-Aug-22      yes     internal           NaN           NaN
# 6  ABC-1           NaN      yes     internal           NaN      on track
# 7  ABC-4           NaN      yes     internal           NaN      on track
# 8  ABC-5           NaN      yes     internal           NaN      on track
# 9  ABC-6           NaN      yes     internal           NaN       delayed
#
#   login date places date
# 0  31-Jul-22         NaN
# 1  04-Mar-22         NaN
# 2  15-May-21         NaN
# 3  20-May-23         NaN
# 4        NaN         NaN
# 5        NaN         NaN
# 6  31-May-22   02-Jul-21
# 7  17-Apr-23   01-May-23
# 8  04-Sep-21   01-Oct-21
# 9  06-Aug-22   17-Aug-22

# %%
df_a[['Prefix', 'Suffix']] = df_a['ID'].str.extract(r'(\D+)-(\d+)')

# %%
# Create pandas DataFrames from the sample data
df_a = pd.DataFrame(data_a)
df_b = pd.DataFrame(data_b)

# Function to perform replacements directly in dataset A
def replace_values(row):
    if row['tracking'] == 'yes' and row['confidential'] == 'internal':
        b_row = df_b[df_b['ID'] == row['ID']]
        if not b_row.empty:
            row['status'] = b_row['status'].values[0]
            row['login date'] = b_row['login date'].values[0]
    return row

# Apply the function to perform replacements
df_a = df_a.apply(replace_values, axis=1)

# Print the updated dataset A
print(df_a)

# %%
df['login date'] = pd.to_datetime(df['login date'], format='%d-%b-%y')

# %%
# Calculate the date 30 days ago from the current date
thirty_days_ago = datetime.now() - timedelta(days=30)

# Filter the data based on the given conditions
filtered_data = df[
    (df['login date'] >= thirty_days_ago) &
    ((df['status'] == 'Closed') | (df['status'] == 'Closed-ABC')) &
    (~df['status'].str.contains('closed-cancel', case=False))
]

# %%
import pandas as pd
from datetime import datetime, timedelta

# Read the Excel file
df = pd.read_excel('path_to_your_excel_file.xlsx')

# Convert the 'login date' column to datetime format
df['login date'] = pd.to_datetime(df['login date'])

# Get the current date
current_date = datetime.now()

# Calculate the date 30 days ago from the current date
thirty_days_ago = current_date - timedelta(days=30)

# Apply the filters
filtered_data = df[
    ((df['login date'] >= thirty_days_ago) & (df['login date'] <= current_date)) &  # Last 30 days
    ((df['status'] == 'Closed') | (df['status'] == 'Closed-ABC')) &                  # Status: Closed or Closed-ABC
    (~(df['status'].str.contains('Closed-cancel'))) &                                # Exclude status containing 'Closed-cancel'
    (~(df['status'].str.contains('closed-cancel(publis)')))                         # Exclude status containing 'closed-cancel(publis)'
]

# Display the filtered data
print(filtered_data)

# %%
from openpyxl import load_workbook
from datetime import datetime, timedelta

# Load the Excel file
wb = load_workbook('path_to_your_excel_file.xlsx')
ws = wb.active

# Get the current date
current_date = datetime.now()

# Calculate the date 30 days ago from the current date
thirty_days_ago = current_date - timedelta(days=30)

# Create a new list to store the filtered rows
filtered_rows = []

# Iterate through each row in the Excel sheet
for row in ws.iter_rows(min_row=2, values_only=True):
    login_date = row[2]  # Assuming 'login date' is in the third column (index 2)
    status = row[1]      # Assuming 'status' is in the second column (index 1)

    # Check if the row meets the filtering criteria
    if (
        (login_date >= thirty_days_ago) and (login_date <= current_date) and   # Last 30 days
        (status in ['Closed', 'Closed-ABC']) and                              # Status: Closed or Closed-ABC
        ('Closed-cancel' not in status) and                                    # Exclude status containing 'Closed-cancel'
        ('closed-cancel(publis)' not in status)                                # Exclude status containing 'closed-cancel(publis)'
    ):
        filtered_rows.append(row)

# Display the filtered data
header_row = ws[1]
filtered_data = [header_row] + filtered_rows

for row in filtered_data:
    print(row)

# %%
import pandas as pd
from datetime import datetime, timedelta

# Read the Excel file
df = pd.read_excel('path_to_your_excel_file.xlsx')

# Convert the 'login date' column to datetime format
df['login date'] = pd.to_datetime(df['login date'])

# Get the current date
current_date = datetime.now()

# Calculate the date 30 days ago from the current date
thirty_days_ago = current_date - timedelta(days=30)

# Filter the data for all the status except 'Closed'
filtered_data = df[df['status'] != 'Closed']

# Filter the data for 'Closed' and 'Closed-ABC' status within the last 30 days
closed_data_last_30_days = df[
    ((df['login date'] >= thirty_days_ago) & (df['login date'] <= current_date)) &
    (df['status'].isin(['Closed', 'Closed-ABC']))
]

# Concatenate both filtered datasets
result_data = pd.concat([filtered_data, closed_data_last_30_days])

# Display the result
print(result_data)

# %%
import pandas as pd
from datetime import datetime, timedelta

# Read the Excel file
df = pd.read_excel('path_to_your_excel_file.xlsx')

# Convert the 'login date' column to datetime format
df['login date'] = pd.to_datetime(df['login date'])

# Get the current date
current_date = datetime.now()

# Calculate the date 30 days ago from the current date
thirty_days_ago = current_date - timedelta(days=30)

# Filter the data for all the statuses except 'Closed-Cancel' and 'closed-cancel(publis)'
filtered_data = df[~df['status'].isin(['Closed- Cancel', 'closed-cancel(publis)'])]

# Filter the data for 'Closed-ABC' status within the last 30 days
closed_abc_last_30_days = df[
    ((df['login date'] >= thirty_days_ago) & (df['login date'] <= current_date)) &
    (df['status'] == 'Closed-ABC')
]

# Concatenate both filtered datasets
result_data = pd.concat([filtered_data, closed_abc_last_30_days])

# Display the result
print(result_data)
